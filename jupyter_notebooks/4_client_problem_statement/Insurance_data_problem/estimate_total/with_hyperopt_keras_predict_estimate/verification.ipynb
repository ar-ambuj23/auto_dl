# %%
import pandas as pd

# %%
train_o = pd.read_pickle('train_insurance_2017_new.pkl')
valid_o = pd.read_pickle('valid_insurance_2017_new.pkl')

# %%
a = pd.concat([train_o,valid_o])

# %%
b = pd.read_csv('training_results.csv',index_col = 0)

# %%
ori = pd.read_csv('cleaned_insurance_data_with_year.csv',index_col = 0)
# Out:
# /home/ambuj/izenda_fullcycle/lib/python3.6/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
a.head()
# Out:
#          StartedFlag  NoteCount  PhotoCount  JobCount  ClaimCount  LossYearMo  \
# index
# 1128074            1      638.0        84.0       5.0         5.0          10
# 1976028            0        5.0         0.0       1.0         1.0          11
# 477573             0        8.0         0.0       1.0         1.0           4
# 1088328            1       12.0         3.0       1.0         1.0          10
# 999197             1      210.0         3.0       1.0         1.0          10
#
#          NewEstimateTotal  State_0  State_AB  State_AK          ...            \
# index                                                           ...
# 1128074                 1        0         0         0          ...
# 1976028                 0        0         0         0          ...
# 477573                  0        0         0         0          ...
# 1088328                 0        0         0         0          ...
# 999197                  1        0         0         0          ...
#
# ...

# %%
b.head()
# Out:
#                                    DivisionName         DisplayName State  \
# index
# 1128074                               Structure             Default    TN
# 1976028                      Structural Repairs  Structural Repairs    IN
# 477573                                    Water    Water Mitigation    CA
# 1088328                        Water Mitigation    Water Mitigation    NY
# 999197   Emergency Services - Multiple Services             Default    NC
#
#            CommOrRes  StartedFlag  NoteCount  PhotoCount  JobCount  \
# index
# 1128074  Residential            1      638.0        84.0       5.0
# 1976028  Residential            0        5.0         0.0       1.0
# 477573   Residential            0        8.0         0.0       1.0
# 1088328  Residential            1       12.0         3.0       1.0
# 999197   Residential            1      210.0         3.0       1.0
#
#          ClaimCount  LossYearMo  NewEstimateTotal  probability  preds
# index
# ...

# %%
ori[ori.index == 1128074]
# Out:
#          LossYearMo          City State    Zip DivisionName  StartedFlag  \
# 1128074      201610  MURFREESBORO    TN  37130    Structure            1
#
#         DisplayName    CommOrRes  NoteCount  PhotoCount  JobCount  ClaimCount  \
# 1128074     Default  Residential      638.0        84.0       5.0         5.0
#
#          EstimateTotal  LossMo  LossYear
# 1128074      144081.45      10      2016

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(b.NewEstimateTotal,b.preds)
# Out:
# 0.7494426956985478
