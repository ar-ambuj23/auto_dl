# %%
# Test Database: server=69.199.10.87,51512;Database=Retail;User ID=retail;Password=asfa0Aasdjfasdf;

# %%
import pymssql
import pandas as pd

# %%
# Setting up a connection with the database
conn = pymssql.connect(server="69.199.10.87",    
                     user="retail",         
                     password="asfa0Aasdjfasdf",  
                     database="Retail",
                    port = 51512)

# %%
# Reading table schema as a pandas df
df = pd.read_sql("""SELECT * FROM sys.Tables""",conn)

# %%
df
# Out:
#                    name   object_id principal_id  schema_id  parent_object_id  \
# 0          OrderRegions    18099105         None          1                 0
# 1                Orders    34099162         None          1                 0
# 2              Products    82099333         None          1                 0
# 3                Region   194099732         None          1                 0
# 4              Shippers   210099789         None          1                 0
# 5             Suppliers   242099903         None          1                 0
# 6            Categories   245575913         None          1                 0
# 7           Territories   274100017         None          1                 0
# 8             Customers   277576027         None          1                 0
# 9             Employees   309576141         None          1                 0
# 10  EmployeeTerritories   341576255         None          1                 0
# ...

# %%
# Storing all the 13 tables in a dictionary
table_dict = {}

for db in list(df['name']):
    print(db)
    table_dict[db] = pd.read_sql('SELECT * FROM "{}"'.format(db),conn)
    table_dict[db].to_csv('sample_data/{}.csv'.format(db))
# Out:
# OrderRegions
# Orders
# Products
# Region
# Shippers
# Suppliers
# Categories
# Territories
# Customers
# Employees
# EmployeeTerritories
# EmpTest
# Order Details

# %%
table_dict.keys()
# Out:
# dict_keys(['OrderRegions', 'Orders', 'Products', 'Region', 'Shippers', 'Suppliers', 'Categories', 'Territories', 'Customers', 'Employees', 'EmployeeTerritories', 'EmpTest', 'Order Details'])

# %%
# To visualise the contents of each table

# %%
test = table_dict['Order Details']

# %%
test.shape
# Out:
# (2231, 5)

# %%
test
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# 5       10250         41       7.70        10      0.00
# 6       10250         51      42.40        35      0.15
# 7       10250         65      16.80        15      0.15
# 8       10251         22      16.80         6      0.05
# 9       10251         57      15.60        15      0.05
# 10      10251         65      16.80        20      0.00
# 11      10252         20      64.80        40      0.05
# 12      10252         33       2.00        25      0.05
# 13      10252         60      27.20        40      0.00
# 14      10253         31      10.00        20      0.00
# 15      10253         39      14.40        42      0.00
# ...
